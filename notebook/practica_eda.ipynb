# %% [markdown]
# # Práctica: EDA Completo — Transacciones E-commerce Q3 2025
#
# Sigue el checklist de EDA sección por sección. No modifiques las celdas de instrucciones.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## 1. Carga y primera inspección
#
# Lee `../data/ecommerce_transactions.csv`. Muestra:
# - `shape` — ¿cuántas filas y columnas?
# - `dtypes` — ¿los tipos son correctos?
# - `head()` — primeras filas
# - `describe()` — estadísticas de las numéricas
# - `info()` — resumen general

# %%
# Tu código aquí

# %% [markdown]
# ## 2. Calidad de datos
#
# Investiga:
# - ¿Hay **valores nulos**? ¿En qué columnas? ¿Qué porcentaje?
# - ¿Hay **duplicados**? ¿Filas enteras o solo `order_id` duplicados?
# - ¿Hay **inconsistencias**? (valores negativos, rangos imposibles, etc.)
#
# Documenta cada problema encontrado y decide qué hacer con él.

# %%
# Tu código aquí

# %% [markdown]
# ## 3. Distribuciones univariantes
#
# Para cada variable numérica relevante: histograma.
# Para cada categórica: `value_counts()` + bar chart.
#
# Busca: ¿hay alguna distribución que te sorprenda? ¿Algo asimétrico?

# %%
# Tu código aquí

# %% [markdown]
# ## 4. Análisis bivariante y correlaciones
#
# Explora relaciones entre variables:
# - ¿Cómo se relaciona `product_category` con `total_amount`?
# - ¿Qué `payment_method` se usa más por segmento?
# - ¿Hay diferencias por `shipping_region`?
# - Heatmap de correlaciones numéricas
# - Al menos 2 scatter plots o groupby interesantes

# %%
# Tu código aquí

# %% [markdown]
# ## 5. Outliers
#
# Identifica valores atípicos:
# - Boxplots de `unit_price`, `total_amount`, `quantity`
# - ¿Cuántos outliers hay? ¿Son errores o valores legítimos?
# - Criterio: IQR, z-score u otro justificado

# %%
# Tu código aquí

# %% [markdown]
# ## 6. Hallazgos (mínimo 5)
#
# Documenta cada hallazgo con este formato:
#
# ### Hallazgo 1: [título]
# **Evidencia:** [referencia al gráfico o estadística]
# **Implicación de negocio:** [qué debería hacer la empresa con esto]
#
# ### Hallazgo 2: [título]
# **Evidencia:** ...
# **Implicación de negocio:** ...
#
# ### Hallazgo 3: [título]
# **Evidencia:** ...
# **Implicación de negocio:** ...
#
# ### Hallazgo 4: [título]
# **Evidencia:** ...
# **Implicación de negocio:** ...
#
# ### Hallazgo 5: [título]
# **Evidencia:** ...
# **Implicación de negocio:** ...

# %% [markdown]
# ## 7. Resumen ejecutivo
#
# Escribe un párrafo (máximo 150 palabras) para tu manager resumiendo:
# - Estado general de los datos
# - Los 2-3 insights más importantes
# - Siguiente paso recomendado

# %% [markdown]
# *Escribe tu resumen ejecutivo aquí...*
